# %% [markdown]
# <a href="https://colab.research.google.com/github/Harry1402/Neural_network_from_scratch/blob/main/Neural_Network7_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# solving for x
# e**x = b

import numpy as np
import math
b= 5.2

print(np.log(b))
print(math.e**1.23242424)
# Out:
# 1.6486586255873816
# 3.4295334790890606

# %%
import math

softmax_putput =[0.2,0.1,0.3]

target_output=[1,0,0]

loss =-(math.log(softmax_putput[0])*target_output[0]+
        math.log(softmax_putput[1])*target_output[1]+
        math.log(softmax_putput[2])*target_output[2])

print(loss)
print(softmax_putput[0])

loss1 = -math.log(softmax_putput[0])
print(loss1)
# Out:
# 1.6094379124341003
# 0.2
# 1.6094379124341003
