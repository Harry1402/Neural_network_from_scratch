# %% [markdown]
# <a href="https://colab.research.google.com/github/Harry1402/Neural_network_from_scratch/blob/main/Neural_network5_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np ;
import  nnfs;
from nnfs.datasets import spiral_data;

nnfs.init();


X,Y = spiral_data(100,3)

class Layer_Dense:
  def __init__(self,n_inputswa,n_neuronswa):
    self.weights =0.10 * np.random.randn(n_inputswa ,n_neuronswa) #(rows,colums)
    self.biases=np.zeros((1,n_neuronswa))
  def forward(self ,inputs):
    self.output=np.dot(inputs,self.weights)+self.biases


class Activation_Relu:
  def forward(self,inputs):
    self.output=np.maximum(0,inputs)


layer1 = Layer_Dense(X.shape[1],5)
layer1.forward(X)

activation1 =Activation_Relu()
activation1.forward(layer1.output)


print(layer1.output);
print(activation1.output)
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00]
#  [-8.35815910e-04 -7.90404272e-04 -1.33452227e-03  4.65504505e-04
#    4.56846210e-05]
#  [-2.39994470e-03  5.93469958e-05 -2.24808278e-03  2.03573116e-04
#    6.10024377e-04]
#  ...
#  [ 1.13291524e-01 -1.89262271e-01 -2.06855070e-02  8.11079666e-02
#   -6.71350807e-02]
#  [ 1.34588361e-01 -1.43197834e-01  3.09493970e-02  5.66337556e-02
#   -6.29687458e-02]
#  [ 1.07817926e-01 -2.00809643e-01 -3.37579325e-02  8.72561932e-02
#   -6.81458861e-02]]
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 4.65504505e-04
#   4.56846210e-05]
#  [0.00000000e+00 5.93469958e-05 0.00000000e+00 2.03573116e-04
#   6.10024377e-04]
#  ...
#  [1.13291524e-01 0.00000000e+00 0.00000000e+00 8.11079666e-02
#   0.00000000e+00]
#  [1.34588361e-01 0.00000000e+00 3.09493970e-02 5.66337556e-02
#   0.00000000e+00]
# ...
